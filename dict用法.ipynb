# %%
dict = {'Name': 'Runoob', 'Age': 7, 'Class': 'First'}
print(dict['Name'])
# Out:
# Runoob

# %%
dict['peter']=90

# %%
dict
# Out:
# {'Name': 'Runoob', 'Age': 7, 'Class': 'First', 'peter': 90}

# %%
dict.update({"yyh":0})
dict
# Out:
# {'Name': 'Runoob', 'Age': 7, 'Class': 'First', 'peter': 90, 'yyh': 0}

# %%
list=["hel",2,'yyh',5]
for i in list:
    print(i)
# Out:
# hel
# 2
# yyh
# 5

# %%
res=[[],[]]

# %%
res[0]
# Out:
# []

# %%
path1=[1,2,3,4]
path2=[3,4,5,6]
res[0].append(path1[:])
res[1].append(path2[:])
res
# Out:
# [[[1, 2, 3, 4]], [[3, 4, 5, 6]]]

# %%
path3=[2,4,5,6]
res[0].append(path3[:])

# %%
res
# Out:
# [[[1, 2, 3, 4], [2, 4, 5, 6]], [[3, 4, 5, 6]]]

# %%
len(res)
# Out:
# 2

# %%
len(res[0])
# Out:
# 2

# %%
len(res[1])
# Out:
# 1
